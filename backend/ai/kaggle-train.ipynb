# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks

# %%
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))

# %%
import wandb
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient() 

personal_key_for_api = user_secrets.get_secret("wandb")

# !wandb login $personal_key_for_api

# %%
project='bitirme-calismasi '
name='yolov5l6'

# %%
# Create YAML custom yaml is not working
# %cd /kaggle/working
text_to_write = "train: /kaggle/input/bitirme-calismasi-3/train\nval: /kaggle/input/bitirme-calismasi-3/validation\ntest: /kaggle/input/bitirme-calismasi-3/test\n\n# number of classes\nnc: 10\n\n# class names\nnames: ['Blender', 'Coffeemaker', 'Microwave oven', 'Gas stove', 'Mixing bowl', 'Couch', 'Refrigerator', 'Washing machine', 'Bed', 'Television']\n"
with open("/kaggle/working/custom-dataset.yaml",'w') as f:
    print(f.write(text_to_write))

# %%
custom_cfg_yaml = '/kaggle/working/custom-dataset.yaml'
yolo_cfg_yaml = '/kaggle/input/bitirme-calismasi-3/yolov5.yaml'
custom_weight = '/kaggle/input/bitirme-calismasi-3/weights/yolov5l6.pt'

# %%
# !python train.py --batch 16 --epochs 75 --data {custom_cfg_yaml} --weights {custom_weight} --cfg {yolo_cfg_yaml} --cache --project {project} --name {name}

# %%
# %cd /kaggle/working

# %%
path_list = [os.path.join('/kaggle/working','file.zip') for dirpath, _, filenames in os.walk('.') for filename in filenames if filename.endswith('.zip')]
path_list

# %%
# !zip -r file.zip /kaggle/working

# %%
from glob import glob

files = []
start_dir = os.getcwd()
pattern   = "*.zip"

for dir,_,_ in os.walk(start_dir):
    files.extend(glob(os.path.join(dir,pattern))) 
print(files)

# %%
# %cd /kaggle/working/yolov5/
from IPython.display import FileLink
FileLink(r'/kaggle/working/yolov5/bitirme-calismasi/yolov5l6/file.zip')
